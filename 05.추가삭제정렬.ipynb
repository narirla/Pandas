# %%
import pandas as pd
import numpy as np

# %%
data =  {'eng':[10,30,50,70,60],
         'kor':[20,40,60,80,75],
         'math':[90,50,20,70,30]}
df = pd.DataFrame(data, index=['a','b','c','d','e'] )
df
# Out:
#    eng  kor  math
# a   10   20    90
# b   30   40    50
# c   50   60    20
# d   70   80    70
# e   60   75    30

# %% [markdown]
# ### 추가

# %% [markdown]
# ### 컬럼 추가

# %%
df['test'] = [1,2,3,4,5]  # 컬럼이 有면 수정, 無면 추가

# %%
df['eng'] + df['kor']
# Out:
# a     30
# b     70
# c    110
# d    150
# e    135
# dtype: int64

# %%
df['sum'] = df['eng'] + df['kor']

# %%
df.insert(1, 'test1',[1,2,3,4,5]) # df.insert(추가할 컬럼인덱스(위치), 추가할 인덱스 명, 추가할 값)

# %% [markdown]
# ### 행추가

# %%
df.loc['f'] = [1,2,3] # 해당 인덱스가 有면 수정, 無면 추가
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.loc['f'] = [1,2,3] # 해당 인덱스가 有면 수정, 無면 추가
#
# File c:\Python310\lib\site-packages\pandas\core\indexing.py:912, in _LocationIndexer.__setitem__(self, key, value)
#     909 self._has_valid_setitem_indexer(key)
#     911 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 912 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Python310\lib\site-packages\pandas\core\indexing.py:1933, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1930     indexer, missing = convert_missing_indexer(indexer)
#    1932     if missing:
# -> 1933         self._setitem_with_indexer_missing(indexer, value)
#    1934         return
#    1936 if name == "loc":
#    1937     # must come after setting of missing
#
# ...

# %% [markdown]
# ### 삭제
# - drop( index=[부여된인덱스명,...], colums=[부여된컬럼명,....] )

# %%
# df = df.drop( index=['a','c','d'])
# df.drop( index=['a','c','d'], inplace=True) # inplace=True 를 주게 되면 삭제된 값이 바로 반영됨
df.drop( index=['a','c','d'] )
# Out:
#    eng  kor  math
# b   30   40    50
# e   60   75    30

# %%
df.drop( columns=['eng','math'])
# Out:
#    kor
# a   20
# b   40
# c   60
# d   80
# e   75

# %%
df.drop(index=['a','d'], columns=['kor']) # drop은 행열 모두 삭제 가능
# Out:
#    eng  math
# b   30    50
# c   50    20
# e   60    30

# %%
df.drop(index=['a','d'], axis=0) #axis=0(행) a와 d를 인덱스명으로 인식하여 삭제함
# Out:
#    eng  kor  math
# b   30   40    50
# c   50   60    20
# e   60   75    30

# %%
df.drop(columns=['kor'], axis=1) #axis=1 컬럼으로 인식하여 'kor'을 삭제
# Out:
#    eng  math
# a   10    90
# b   30    50
# c   50    20
# d   70    70
# e   60    30

# %% [markdown]
# ### 정렬

# %%
df.sort_values(by='math') #기준 컬럼을 必 지정해줘야함
# Out:
#    eng  kor  math
# c   50   60    20
# e   60   75    30
# b   30   40    50
# d   70   80    70
# a   10   20    90

# %%
df.sort_values(by='math', ascending=False) #내림차순
# Out:
#    eng  kor  math
# a   10   20    90
# d   70   80    70
# b   30   40    50
# e   60   75    30
# c   50   60    20

# %%
df.loc['c','kor'] = 40

# %%
df.sort_values(by=['kor','math']) # 1차 정렬은 국어로 하고 2차 정렬은 수학으로 정렬
# Out:
#    eng  kor  math
# a   10   20    90
# c   50   40    20
# b   30   40    50
# e   60   75    30
# d   70   80    70

# %%
df.sort_index(ascending=False) #내림차순
# Out:
#    eng  kor  math
# e   60   75    30
# d   70   80    70
# c   50   40    20
# b   30   40    50
# a   10   20    90

# %%
df.sort_index(axis=1, ascending=False) #인덱스를 컬럼 정렬해서 알파벳 역순으로 정렬
# Out:
#    math  kor  eng
# a    90   20   10
# b    50   40   30
# c    20   40   50
# d    70   80   70
# e    30   75   60

# %%
df
# Out:
#    eng  kor  math
# a   10   20    90
# b   30   40    50
# c   50   40    20
# d   70   80    70
# e   60   75    30
