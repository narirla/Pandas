# %%
import pandas as pd
import numpy as np

# %%
data = {'aa':10, 'bb':20, 'cc':30, 'dd':40, 'ee': 50}
sr = pd.Series(data, name= '국어점수')
sr
# Out:
# aa    10
# bb    20
# cc    30
# dd    40
# ee    50
# Name: 국어점수, dtype: int64

# %%
sr.ndim
# Out:
# 1

# %%
sr.size
# Out:
# 5

# %%
sr.shape
# Out:
# (5,)

# %%
sr.dtype
# Out:
# dtype('int64')

# %%
sr.index #인덱스만 추출, 리스트는 아님, 인덱스 클래스의 속성 메소드 호출 가능
# Out:
# Index(['aa', 'bb', 'cc', 'dd', 'ee'], dtype='object')

# %%
print(type(sr.index))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
sr.values #ndarray
# Out:
# array([10, 20, 30, 40, 50])

# %%
print(type(sr.values))
# Out:
# <class 'numpy.ndarray'>

# %%
sr.values.sum()
# Out:
# np.int64(150)

# %%
sr.name #라벨링 값을 가져옴
# Out:
# '국어점수'
