# %%
import pandas as pd
import numpy as np

# %%
data = {'aa':10, 'bb':20, 'cc':30, 'dd':40, 'ee': 50}
sr = pd.Series(data, name= '국어점수')
sr
# Out:
# aa    10
# bb    20
# cc    30
# dd    40
# ee    50
# Name: 국어점수, dtype: int64

# %% [markdown]
# - 인덱싱
# - 0,1,2,3,.....
# - ....,-3,-2,-1
# - 부여된 인덱스 명

# %%
sr[0]
# Out:
# C:\Users\Dell3571\AppData\Local\Temp\ipykernel_9368\3717362250.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sr[0]
# np.int64(10)

# %%
sr[-1]
# Out:
# C:\Users\Dell3571\AppData\Local\Temp\ipykernel_9368\484977753.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sr[-1]
# np.int64(50)

# %%
sr['aa'] #문자열 numpy 無
# Out:
# np.int64(10)

# %%
sr.aa #부여된 인덱스명도 사용가능 단,속성명과 겹치면 오류 발생
# Out:
# np.int64(10)

# %% [markdown]
# - 복수 개 인덱싱
# - [[인덱스번호,....]]
# - [[부여된인덱스번호,.....]]

# %%
sr[[1,3,4]]
# Out:
# C:\Users\Dell3571\AppData\Local\Temp\ipykernel_9368\2032156101.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sr[[1,3,4]]
# bb    20
# dd    40
# ee    50
# Name: 국어점수, dtype: int64

# %%
sr[['aa','cc','dd']] #부여된 인덱스 명
# Out:
# aa    10
# cc    30
# dd    40
# Name: 국어점수, dtype: int64

# %% [markdown]
# ### 슬라이싱
# - [시작인덱스:끝인덱스:증가치]
# - [부여된 시작 인덱스 명:부여된 끝인덱스 명]
# 부여된 시작인덱스명<=index<=부여된 끝인덱스명

# %%
sr[1:4]
# Out:
# bb    20
# cc    30
# dd    40
# Name: 국어점수, dtype: int64

# %%
sr['bb':'dd'] #부여된 인덱스명으로 할 경우 끝인덱스도 포함되어 나옴
# Out:
# bb    20
# cc    30
# dd    40
# Name: 국어점수, dtype: int64

# %%
sr['bb':'ee':2]
# Out:
# bb    20
# dd    40
# Name: 국어점수, dtype: int64

# %%
sr
# Out:
# aa    10
# bb    20
# cc    30
# dd    40
# ee    50
# Name: 국어점수, dtype: int64

# %% [markdown]
# - iloc[]: zero base 로 고정 (부여된 인덱스명 X)

# %%
sr.iloc[0] #sr.[0]
# Out:
# np.int64(10)

# %%
sr.iloc[-1]
# Out:
# np.int64(50)

# %%
sr.iloc[[1,3]]
# Out:
# bb    20
# dd    40
# Name: 국어점수, dtype: int64

# %%
sr.iloc[1:4]
# Out:
# bb    20
# cc    30
# dd    40
# Name: 국어점수, dtype: int64

# %%
# sr.iloc['aa'] X
# sr.iloc['aa':'cc'] X

# %% [markdown]
# # loc[] : 부여된 인덱스명(zerobase X)으로 고정

# %%
sr.loc['aa'] #sr.loc[0] X
# Out:
# np.int64(10)

# %%
sr.loc[['aa','dd']]
# Out:
# aa    10
# dd    40
# Name: 국어점수, dtype: int64

# %%
sr.loc['bb':'dd']
# Out:
# bb    20
# cc    30
# dd    40
# Name: 국어점수, dtype: int64

# %%
sr.index = [2,3,4,5,6]

# %%
sr
# Out:
# 2    10
# 3    20
# 4    30
# 5    40
# 6    50
# Name: 국어점수, dtype: int64

# %%
sr[2] ##인덱스가 숫자 타입이면 자동으로 부여된 인덱스명으로 설정됨
# Out:
# np.int64(10)

# %%
sr.iloc[2]
# Out:
# np.int64(30)

# %%
sr.loc[2]
# Out:
# np.int64(10)

# %%
sr.iloc[-1]
# Out:
# np.int64(50)

# %%
sr.loc[3:5] #부여된 인덱스  #sr.index = [2,3,4,5,6] 현재 변경된 인덱스
# Out:
# 3    20
# 4    30
# 5    40
# Name: 국어점수, dtype: int64

# %%
sr.iloc[3:5]
# Out:
# 5    40
# 6    50
# Name: 국어점수, dtype: int64

# %%
# sr[-1]  #error

# %% [markdown]
# 결론 : sr 자체로 인덱스 슬라이싱 사용 X
# 반드시 iloc, loc 사용 必 --> 혼돈 방지를 위해
