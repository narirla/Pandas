# %%
import pandas as pd
import numpy as np

# %%
data =  {'eng':[10,30,50,70,60],
         'kor':[20,40,60,80,75],
         'math':[90,50,20,70,30]}
df = pd.DataFrame(data, index=['a','b','c','d','e'] )
df
# Out:
#    eng  kor  math
# a   10   20    90
# b   30   40    50
# c   50   60    20
# d   70   80    70
# e   60   75    30

# %% [markdown]
# ### 인덱싱
# - ['부여된컬럼명']
# - [ ['컬럼명','컬럼명'] ]

# %%
df
# Out:
#    eng  kor  math
# a   10   20    90
# b   30   40    50
# c   50   60    20
# d   70   80    70
# e   60   75    30

# %%
df['eng'] #.시리즈함수()
# Out:
# a    10
# b    30
# c    50
# d    70
# e    60
# Name: eng, dtype: int64

# %%
df['eng'].sum()
# Out:
# np.int64(220)

# %%
sr = df['eng']
sr.sum() #참조변수가 있어 메모리가 계속 살아있음, 데이터양을 많이 잡아먹음
# Out:
# np.int64(220)

# %%
df[['eng','kor']] #데이터프레임객체로 출력 .속성메소드 호출
# Out:
#    eng  kor
# a   10   20
# b   30   40
# c   50   60
# d   70   80
# e   60   75

# %% [markdown]
# ### 슬라이싱(행단위)
# - [시작인덱스:끝인덱스:증가치]
# - [부여된인덱스:부여된인덱스]

# %%
df[1:4]
# Out:
#    eng  kor  math
# b   30   40    50
# c   50   60    20
# d   70   80    70

# %%
df['b':'c']
# Out:
#    eng  kor  math
# b   30   40    50
# c   50   60    20

# %% [markdown]
# ### iloc : zero base
# - [행,열]

# %%
df.iloc[0] #0행 출력, 시리즈
# Out:
# eng     10
# kor     20
# math    90
# Name: a, dtype: int64

# %%
df.iloc[0,0] #0행0열
# Out:
# np.int64(10)

# %%
df.iloc[1,2]
# Out:
# np.int64(50)

# %%
df.iloc[[1,3]]
# Out:
#    eng  kor  math
# b   30   40    50
# d   70   80    70

# %%
df.iloc[1:]
# Out:
#    eng  kor  math
# b   30   40    50
# c   50   60    20
# d   70   80    70
# e   60   75    30

# %%
df.iloc[1:4]
# Out:
#    eng  kor  math
# b   30   40    50
# c   50   60    20
# d   70   80    70

# %%
df.iloc[1:4, 1:]
# Out:
#    kor  math
# b   40    50
# c   60    20
# d   80    70

# %%
df.iloc[[1,3], [0,2]]
# Out:
#    eng  math
# b   30    50
# d   70    70

# %%
df
# Out:
#    eng  kor  math
# a   10   20    90
# b   30   40    50
# c   50   60    20
# d   70   80    70
# e   60   75    30

# %%
### Q)
df.iloc[[1,3,4],[0,2]]
# df.iloc[[1,3,4],::2]
# Out:
#    eng  math
# b   30    50
# d   70    70
# e   60    30

# %% [markdown]
# - loc[]: 부여된 인덱스명, 부여된 칼럼명
# [행,열]

# %%
df.loc['a']
# Out:
# eng     10
# kor     20
# math    90
# Name: a, dtype: int64

# %%
df.loc['a','eng']
# Out:
# np.int64(10)

# %%
df.loc['a':'c'] #a행~c행
# Out:
#    eng  kor  math
# a   10   20    90
# b   30   40    50
# c   50   60    20

# %%
df.loc[['a','c']] # a인덱스, c인덱스
# Out:
#    eng  kor  math
# a   10   20    90
# c   50   60    20

# %%
df.loc['a':'c', 'kor':]
# Out:
#    kor  math
# a   20    90
# b   40    50
# c   60    20

# %%
### Q)
df.loc[['b','d','e'], ['eng','math']]
# Out:
#    eng  math
# b   30    50
# d   70    70
# e   60    30

# %%
df.loc[:,'eng'] # df.['eng]
# Out:
# a    10
# b    30
# c    50
# d    70
# e    60
# Name: eng, dtype: int64

# %%
df
# Out:
#    eng  kor  math
# a   10   20    90
# b   30   40    50
# c   50   60    20
# d   70   80    70
# e   60   75    30
